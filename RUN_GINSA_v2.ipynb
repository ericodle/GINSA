# %% [markdown]
# <a href="https://colab.research.google.com/github/ericodle/GINSA/blob/main/RUN_GINSA_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install required packages

# %%
# !pip install requests
# !pip install wget
# !pip install biopython
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=dee2440a5e7d7e60a9d4a02b9e290cde182e79ad498b70dbc5490b30ab439d12
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Collecting biopython
#   Downloading biopython-1.81-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.22.4)
# Installing collected packages: biopython
# Successfully installed biopython-1.81

# %% [markdown]
# # Import dependent packages

# %%
import urllib.request
import json
import urllib.parse
import os
import csv
import requests
import pandas as pd
import wget
import gzip
import shutil
from Bio import SeqIO
import matplotlib.pyplot as plt

# %% [markdown]
# # Script functions

# %%
###############################################################################################################################

def search_species_occurrences(species_name, limit=300):
    base_url = "https://api.gbif.org/v1/occurrence/search"
    params = {
        "scientificName": species_name,
        "limit": limit,
    }

    occurrence_ids = []

    offset = 0
    while True:
        params["offset"] = offset
        encoded_params = urllib.parse.urlencode(params)
        full_url = f"{base_url}?{encoded_params}"

        with urllib.request.urlopen(full_url) as response:
            data = json.loads(response.read())

            if "results" in data:
                occurrence_ids.extend([occurrence["key"] for occurrence in data["results"]])
                if len(data["results"]) < limit:
                    break  # Reached the end of results
                else:
                    offset += limit
            else:
                break

    return occurrence_ids

###############################################################################################################################

def create_folders(occurrence_ids, proj_dir):
    if not os.path.exists(proj_dir):
        os.makedirs(proj_dir)

    for occurrence_id in occurrence_ids:
        folder_path = os.path.join(proj_dir, str(occurrence_id))
        os.makedirs(folder_path, exist_ok=True)

###############################################################################################################################

def generate_csv(occurrence_ids, proj_dir):
    with open(proj_dir + '/occurrences.csv', mode='w', newline='') as csv_file:
        fieldnames = ['occurrence_id', 'latitude', 'longitude', 'prefix_text']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

        writer.writeheader()

        for occurrence_id in occurrence_ids:
            url = f"https://api.gbif.org/v1/occurrence/{occurrence_id}"
            response = requests.get(url)

            if response.status_code == 200:
                try:
                    data = response.json()
                    long_id = data.get("occurrenceID")
                    if long_id:
                        print(long_id)  # debug line
                        latitude = data.get("decimalLatitude")
                        longitude = data.get("decimalLongitude")
                        underscore_index = long_id.find("_")
                        if underscore_index != -1:
                            prefix_text = long_id[:underscore_index]
                        else:
                            prefix_text = "N/A"
                        writer.writerow({
                            'occurrence_id': occurrence_id,
                            'latitude': latitude,
                            'longitude': longitude,
                            'prefix_text': prefix_text
                        })
                    else:
                        print(f"occurrenceID not found for occurrence ID {occurrence_id}. Skipping.")
                except ValueError:
                    print(f"Failed to parse JSON for occurrence ID {occurrence_id}.")
            else:
                print(f"Failed to fetch content for occurrence ID {occurrence_id}. Status code: {response.status_code}")

    print("CSV file created successfully.")

###############################################################################################################################

def process_directory(proj_dir):
    for root, dirs, files in os.walk(proj_dir):
        for file in files:
            if file.endswith(".gz"):
                gz_file_path = os.path.join(root, file)
                extract_path = os.path.splitext(gz_file_path)[0]

                with gzip.open(gz_file_path, 'rb') as f_in, open(extract_path, 'wb') as f_out:
                    shutil.copyfileobj(f_in, f_out)

                os.remove(gz_file_path)
                print(f"Extracted and deleted: {gz_file_path}")

###############################################################################################################################

def ssu_fasta_grab(csv_file, proj_dir):
    # Load the CSV file into a DataFrame
    df = pd.read_csv(csv_file)

    # Replace with your actual MGnify API endpoint
    api_base_url = "https://www.ebi.ac.uk/metagenomics/api/v1"

    # Iterate through the DataFrame and process each occurrence
    for prefix_text, occurrence_id in zip(df['prefix_text'], df['occurrence_id']):

        if pd.isna(prefix_text):  # Check if prefix_text is NaN
            print("MGnify link not found in occurrence metadata.")
            return

        url = f"{api_base_url}/analyses/{prefix_text}/downloads"
        response = requests.get(url)
        data = response.json()

        print(f"Processing {prefix_text}...")

        # Create a directory with the occurrence_id in the project directory
        subdir_path = os.path.join(proj_dir, str(occurrence_id))
        if not os.path.exists(subdir_path):
            os.makedirs(subdir_path)

        fasta_links = []

        # Loop through the data to find links ending with "MERGED_FASTQ_SSU.fasta.gz"
        for entry in data['data']:
            link_entry = entry['links']['self']
            if link_entry.endswith("MERGED_FASTQ_SSU.fasta.gz"):
                fasta_links.append(link_entry)

        if fasta_links:
            print(f"Downloading {len(fasta_links)} file(s) for {prefix_text}...")
            for fasta_link in fasta_links:
                file_name = os.path.basename(fasta_link)
                file_path = os.path.join(subdir_path, file_name)
                wget.download(fasta_link, file_path)
            print("Download complete.")
        else:
            print(f"No fasta files found for {prefix_text}. Saving 'no_fasta.txt'...")
            no_fasta_file = os.path.join(subdir_path, "no_fasta.txt")
            with open(no_fasta_file, "w") as f:
                f.write("No fasta files found.")

        print()  # Add an empty line for better separation

###############################################################################################################################

def mapseq_grab(csv_file, proj_dir):
    # Load the CSV file into a DataFrame
    df = pd.read_csv(csv_file)

    # Replace with your actual MGnify API endpoint
    api_base_url = "https://www.ebi.ac.uk/metagenomics/api/v1"

    # Iterate through the DataFrame and process each occurrence
    for prefix_text, occurrence_id in zip(df['prefix_text'], df['occurrence_id']):

        if pd.isna(prefix_text):  # Check if prefix_text is NaN
            print("MGnify link not found in occurrence metadata.")
            return

        url = f"{api_base_url}/analyses/{prefix_text}/downloads"
        response = requests.get(url)
        data = response.json()

        print(f"Processing {prefix_text}...")

        # Create a directory with the occurrence_id in the project directory
        subdir_path = os.path.join(proj_dir, str(occurrence_id))
        if not os.path.exists(subdir_path):
            os.makedirs(subdir_path)

        mapseq_links = []

        # Loop through the data to find links ending with "MERGED_FASTQ_SSU_MAPSeq.mseq.gz"
        for entry in data['data']:
            link_entry = entry['links']['self']
            if link_entry.endswith("MERGED_FASTQ_SSU_MAPSeq.mseq.gz"):
                mapseq_links.append(link_entry)

        if mapseq_links:
            print(f"Downloading {len(mapseq_links)} file(s) for {occurrence_id}...")
            for mapseq_link in mapseq_links:
                file_name = os.path.basename(mapseq_link)
                file_path = os.path.join(subdir_path, file_name)
                wget.download(mapseq_link, file_path)
            print("Download complete.")
        else:
            print(f"No MAPSeq files found for {occurrence_id}. Saving 'no_mapseq.txt'...")
            no_mapseq_file = os.path.join(subdir_path, "no_mapseq.txt")
            with open(no_mapseq_file, "w") as f:
                f.write("No MAPSeq files found.")

        print()  # Add an empty line for better separation


###############################################################################################################################

def count_occurrences_in_mapseq_file(file_path, species):

    try:
        with open(file_path, 'r') as file:
            content = file.read()

            # Count the occurrences of the species name in the entire file
            num_occurrences = content.count(species)

            if num_occurrences == 0:
                print(f"'{species}' not found in the MAPSEQ file.")
            else:
                print(f"Number of occurrences of '{species}': {num_occurrences}")

            return num_occurrences

    except FileNotFoundError:
        print("Error: The file does not exist or the path is incorrect.")
        return 0
    except Exception as e:
        print(f"An error occurred: {e}")
        return 0

###############################################################################################################################

def find_target_in_mapseq(subdirectory, file_path, species):

    truncated_strings = []  # List to store truncated strings

    try:
        with open(file_path, 'r') as file:
            content = file.readlines()

            for line in content:
                line = line.strip()
                if species in line:
                    # Find the index of the search word in the line
                    word_index = line.index(species)

                    # Extract the preceding string
                    preceding_string = line[:word_index].strip()
                    # Truncate to only the text before the first space
                    truncated_string = preceding_string.split()[0]
                    truncated_strings.append(truncated_string)

        with open(subdirectory+"/truncated_strings.txt", 'w') as output_file:
            for item in truncated_strings:
                output_file.write("%s\n" % item)

    except FileNotFoundError:
        print("MAPSeq Search Error: The file does not exist or the path is incorrect.")
    except Exception as e:
        print(f"An error occurred: {e}")

    return truncated_strings

###############################################################################################################################

def sift_fasta(fasta_file_path, truncated_strings):
    sifted_data = {}  # Dictionary to store truncated_strings and their corresponding DNA sequences

# Parse the FASTA file and extract sequences
    with open(fasta_file_path, "rt") as fasta_file:
        records = SeqIO.parse(fasta_file, "fasta")
        for record in records:
            sequence_name = record.id
            sequence = str(record.seq)

# Search for sequence names in the truncated_strings list
        for truncated_string in truncated_strings:
            if truncated_string in sequence_name:
                sifted_data.setdefault(truncated_string, []).append(sequence)
                break

    return sifted_data
###############################################################################################################################

def save_sifted_data_to_csv(sifted_data, output_file):
    with open(output_file, "w", newline="") as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(["Truncated String", "Sequences"])

        for truncated_string, sequences in sifted_data.items():
            csv_writer.writerow([truncated_string, "\n".join(sequences)])

###############################################################################################################################

def analyze_subdir_mapseq(proj_dir, species):
    # Iterate through subdirectories in proj_dir
    for subdirectory in os.listdir(proj_dir):
        subdir_path = os.path.join(proj_dir, subdirectory)

        # Skip if not a directory
        if not os.path.isdir(subdir_path):
            continue

        print(f"Analyzing subdirectory: {subdirectory}")

        # Check for required files and txt file
        for file_name in os.listdir(subdir_path):
            if file_name.endswith("MERGED_FASTQ_SSU_MAPSeq.mseq"):

                print(file_name)
              # Apply the count_occurrences_in_mapseq_file function
                count_occurrences_in_mapseq_file(subdir_path+"/"+file_name, species)
                find_target_in_mapseq(subdir_path, subdir_path+"/"+file_name, species)
                print("Truncated strings obtained from MAPSeq file.")
            else:
                print("No MAPSeq files found.")

###############################################################################################################################


def analyze_subdir_fasta(proj_dir):
    # Iterate through subdirectories in proj_dir
    for subdirectory in os.listdir(proj_dir):
        subdir_path = os.path.join(proj_dir, subdirectory)

        print("subdirectory path:", subdir_path)

        # Skip if not a directory
        if not os.path.isdir(subdir_path):
            print(f"Skipping non-directory: {subdirectory}")
            continue

        print(f"Analyzing subdirectory: {subdirectory}")

        fasta_files = [file_name for file_name in os.listdir(subdir_path) if file_name.endswith("MERGED_FASTQ_SSU.fasta")]

        # Check if any FASTA files are found in the subdirectory
        if fasta_files:
            # Iterate through FASTA files in the subdirectory
            for fasta_file in fasta_files:
                fasta_filepath = os.path.join(subdir_path, fasta_file)
                print("Found FASTA file:", fasta_filepath)

                # Construct the path for the truncated strings file
                truncated_strings_filepath = os.path.join(subdir_path, "truncated_strings.txt")

                # Perform analysis using sift_fasta and save_sifted_data_to_csv functions
                sifted_data = sift_fasta(fasta_filepath, truncated_strings_filepath)

                # Create a new CSV filename based on the original FASTA filename
                csv_filename = os.path.splitext(fasta_file)[0] + "_extracted_sequences.csv"

                # Save the sifted data to the new CSV file
                save_sifted_data_to_csv(sifted_data, os.path.join(subdir_path, csv_filename))

            print("Extraction and CSV creation complete for all FASTA files.")
        else:
            print("No FASTA files found in the subdirectory.")

###############################################################################################################################


def check_for_csv(subdirectory_path):
    csv_files = [file for file in os.listdir(subdirectory_path) if file.endswith('.csv')]
    return len(csv_files) > 0

##################################################################################################################################

def check_dir(root_directory):
    subdirectories = [d for d in os.listdir(root_directory) if os.path.isdir(os.path.join(root_directory, d))]

    presence_data = []
    for subdir in subdirectories:
        has_csv = check_for_csv(os.path.join(root_directory, subdir))
        presence_data.append(has_csv)

    num_have_csv = presence_data.count(True)
    num_not_have_csv = presence_data.count(False)

    plt.figure(figsize=(6, 6))
    plt.bar(['Sequences Found', 'Sequences Not Found'], [num_have_csv, num_not_have_csv], color=['green', 'red'])
    #plt.xlabel('Project Sub-Folders')
    plt.ylabel('Number of Sub-folders')
    plt.title('Sub-folders Containing Sequences')
    plt.tight_layout()
    plt.show()

##################################################################################################################################

def combine_csv_files(root_directory):
    subdirectories = [d for d in os.listdir(root_directory) if os.path.isdir(os.path.join(root_directory, d))]

    combined_sequences = {}

    for subdir in subdirectories:
        if check_for_csv(os.path.join(root_directory, subdir)):
            subdir_sequences = []
            for csv_file in os.listdir(os.path.join(root_directory, subdir)):
                if csv_file.endswith('.csv'):
                    csv_path = os.path.join(root_directory, subdir, csv_file)
                    csv_content = pd.read_csv(csv_path)
                    if 'Sequences' in csv_content.columns:
                        sequences_data = csv_content['Sequences']
                        subdir_sequences.extend(sequences_data)

            if subdir_sequences:
                combined_sequences[subdir] = subdir_sequences

    if combined_sequences:
        fasta_content = ""
        for subdir, sequences in combined_sequences.items():
            if len(sequences) == 1:
                fasta_content += f">{subdir}\n{sequences[0]}\n"
            else:
                for i, sequence in enumerate(sequences, start=1):
                    fasta_content += f">{subdir}_{i}\n{sequence}\n"

        fasta_path = os.path.join(root_directory, 'seq_master.fasta')
        with open(fasta_path, 'w') as fasta_file:
            fasta_file.write(fasta_content)
        print("Combined sequences saved as 'seq_master.fasta' in the root directory.")
    else:
        print("No sequences found in subdirectories.")

    return fasta_path

##################################################################################################################################

def seq_master_lengths(fasta_file):

    # Read sequences from the FASTA file
    sequences = list(SeqIO.parse(fasta_file, "fasta"))

    # Get sequence names and lengths
    seq_names = [seq.id for seq in sequences]
    seq_lengths = [len(seq) for seq in sequences]

    # Create a bar plot to visualize sequence lengths
    plt.figure(figsize=(10, 6))
    plt.bar(seq_names, seq_lengths, color='blue')
    plt.xlabel('Sequence Names')
    plt.ylabel('Sequence Length')
    plt.title('Sequence Lengths from FASTA File')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()

    # Show the plot
    plt.show()

##################################################################################################################################

def analyze_nucleotide_freqs(fasta_file):

    sequences = list(SeqIO.parse(fasta_file, "fasta"))

    total_sequence = "".join(str(seq_record.seq) for seq_record in sequences)

    # Calculate nucleotide frequencies for the entire fasta file
    nucleotide_freq = {
        'A': total_sequence.count('A'),
        'T': total_sequence.count('T'),
        'C': total_sequence.count('C'),
        'G': total_sequence.count('G')
    }

    # Define colors for each nucleotide
    colors = ['blue', 'orange', 'green', 'red']

    # Plot nucleotide frequencies with colored bars
    plt.figure(figsize=(8, 6))
    bars = plt.bar(nucleotide_freq.keys(), nucleotide_freq.values(), color=colors)
    plt.xlabel('Nucleotides')
    plt.ylabel('Frequency')
    plt.title('Overall Nucleotide Frequencies')
    plt.tight_layout()

    total_count = sum(nucleotide_freq.values())
    print("Overall Nucleotide Frequencies:")
    for nucleotide, count in nucleotide_freq.items():
        print(f"{nucleotide}: {count} ({(count / total_count) * 100:.2f}%)")

    # Show the plot
    plt.show()

##################################################################################################################################

# %% [markdown]
# # Main control function

# %%
def main():

    print("Welcome to the GbIf Next-gen Sequence Analyzer! (GINSA)")

    proj_dir = input("Enter the path to an empty folder for this project.")

    species_name = input("Enter your target taxon in genus-species format (i.e. Lecudina tuzetae). You can also enter Genus alone: ")

    gen_sp = species_name.split()

    if len(gen_sp) == 2:
        genus = gen_sp[0]
        print("Genus: ", genus)
        species = gen_sp[1]
        print("Species: ", species)

    elif len(gen_sp) == 1:
        genus = gen_sp[0]
        print("Genus: ", genus)
        species = gen_sp[0]
        print("Only Genus provided. Search will be based on: ", species)

    elif len(gen_sp) > 2:
        print("Too many search terms.")

    else:
        print("No search taxon entered.")

    occurrence_ids = search_species_occurrences(species_name)

    num_occurrences = len(occurrence_ids)

    if num_occurrences > 0:
        print(f"Number of occurrences found: {num_occurrences}")

    else:
        print("No occurrences found for this taxon.")

    if num_occurrences > 300:
        print("There seem to be many ocurrences of this taxon in GBIF. Please ensure that you have sufficient storage.")

    create_folders(occurrence_ids, proj_dir)
    print("Subdirectory folders created")

    print("Gathering biogeography data on all the occurrences found in GBIF...")
    generate_csv(occurrence_ids, proj_dir)

    print("Occurrence metadata CSV created")
    csv_file = proj_dir+"/occurrences.csv"

    print("Grabbing FASTA and MAPSeq files from MGnify via GBIF...")
    ssu_fasta_grab(csv_file, proj_dir)
    mapseq_grab(csv_file, proj_dir)


    print("Unpacking compressed files...")
    process_directory(proj_dir)

    print("Searching MAPSeq files...")
    analyze_subdir_mapseq(proj_dir, species)

    print("Searching FASTA files...")
    analyze_subdir_fasta(proj_dir)

    print("Sequence acquisition complete! Analyzing your sequences and saving them to a FASTA file.")

    print("Checking sub-folders for new sequences.")
    check_dir(proj_dir)

    print("Aggregaring sequences into a master csv file.")
    fasta_path = combine_csv_files(proj_dir)

    print("Generating a master FASTA file containing your new sequences.")
    seq_master_lengths(fasta_path)

    print("Analyzing the sequences in your master FASTA file.")
    analyze_nucleotide_freqs(fasta_path)

# %% [markdown]
# # Run the script!

# %%
if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Process
# Downloading 1 file(s) for MGYA00593959...
# Download complete.
#
# Processing MGYA00593959...
# Downloading 1 file(s) for MGYA00593959...
# Download complete.
#
# Processing MGYA00594010...
# Downloading 1 file(s) for MGYA00594010...
# Download complete.
#
# Processing MGYA00594010...
# Downloading 1 file(s) for MGYA00594010...
# Download complete.
#
# Processing MGYA00594036...
# Downloading 1 file(s) for MGYA00594036...
# Download complete.
#
# Processing MGYA00594045...
# Downloading 1 file(s) for MGYA00594045...
# Download complete.
#
# Processing MGYA00594053...
# Downloading 1 file(s) for MGYA00594053...
# Download complete.
#
# Processing MGYA00594086...
# Downloading 1 file(s) for MGYA00594086...
# Download complete.
#
# Processing MGYA00185577...
# Downloading 1 file(s) for MGYA00185577...
# Download complete.
#
# Processing MGYA00185581...
# Downloading 1 file(s) for MGYA00185581...
# Download complete.
#
# Processing MGYA00356971...
# No fasta files found for MGYA00356971. Saving 'no_fasta.txt'...
#
# Processing MGYA00357582...
# No fasta files found for MGYA00357582. Saving 'no_fasta.txt'...
#
# Processing MGYA00357645...
# No fasta files found for MGYA00357645. Saving 'no_fasta.txt'...
#
# Processing MGYA00356105...
# No fasta files found for MGYA00356105. Saving 'no_fasta.txt'...
#
# Processing MGYA00356448...
# No fasta files found for MGYA00356448. Saving 'no_fasta.txt'...
#
# Processing MGYA00193822...
# Downloading 1 file(s) for MGYA00193822...
# Download complete.
#
# Processing MGYA00193860...
# Downloading 1 file(s) for MGYA00193860...
# Download complete.
#
# Processing MGYA00193889...
# Downloading 1 file(s) for MGYA00193889...
# Download complete.
#
# Processing MGYA00356643...
# No fasta files found for MGYA00356643. Saving 'no_fasta.txt'...
#
# Processing MGYA00195075...
# No fasta files found for MGYA00195075. Saving 'no_fasta.txt'...
#
# Processing MGYA00195084...
# No fasta files found for MGYA00195084. Saving 'no_fasta.txt'...
#
# Processing MGYA00193789...
# Downloading 1 file(s) for MGYA00193789...
# Download complete.
#
# Processing MGYA00193816...
# Downloading 1 file(s) for MGYA00193816...
# Download complete.
#
# Processing MGYA00193828...
# Downloading 1 file(s) for MGYA00193828...
# Download complete.
#
# Processing MGYA00193831...
# Downloading 1 file(s) for MGYA00193831...
# Download complete.
#
# Processing MGYA00164055...
# Downloading 1 file(s) for MGYA00164055...
# Download complete.
#
# Processing MGYA00164285...
# Downloading 1 file(s) for MGYA00164285...
# Download complete.
#
# Processing MGYA00164888...
# Downloading 1 file(s) for MGYA00164888...
# Download complete.
#
# Processing MGYA00165246...
# Downloading 1 file(s) for MGYA00165246...
# Download complete.
#
# Processing MGYA00165855...
# Downloading 1 file(s) for MGYA00165855...
# Download complete.
#
# Processing MGYA00163691...
# Downloading 1 file(s) for MGYA00163691...
# Download complete.
#
# Processing MGYA00164202...
# Downloading 1 file(s) for MGYA00164202...
# Download complete.
#
# Processing MGYA00164416...
# Downloading 1 file(s) for MGYA00164416...
# Download complete.
#
# Processing MGYA00164957...
# Downloading 1 file(s) for MGYA00164957...
# Download complete.
#
# Processing MGYA00165658...
# Downloading 1 file(s) for MGYA00165658...
# Download complete.
#
# Processing MGYA00166032...
# Downloading 1 file(s) for MGYA00166032...
# Download complete.
#
# Processing MGYA00164335...
# Downloading 1 file(s) for MGYA00164335...
# Download complete.
#
# Processing MGYA00164615...
# Downloading 1 file(s) for MGYA00164615...
# Download complete.
#
# Processing MGYA00165623...
# Downloading 1 file(s) for MGYA00165623...
# Download complete.
#
# Processing MGYA00165856...
# Downloading 1 file(s) for MGYA00165856...
# Download complete.
#
# Processing MGYA00360219...
# No fasta files found for MGYA00360219. Saving 'no_fasta.txt'...
#
# Processing MGYA00360222...
# No fasta files found for MGYA00360222. Saving 'no_fasta.txt'...
#
# Processing MGYA00214227...
# Downloading 1 file(s) for MGYA00214227...
# Download complete.
#
# Processing MGYA00356656...
# No fasta files found for MGYA00356656. Saving 'no_fasta.txt'...
#
# Processing MGYA00175741...
# Downloading 1 file(s) for MGYA00175741...
# Download complete.
#
# Processing MGYA00175745...
# Downloading 1 file(s) for MGYA00175745...
# Download complete.
#
# Processing MGYA00175762...
# Downloading 1 file(s) for MGYA00175762...
# Download complete.
#
# Processing MGYA00175768...
# Downloading 1 file(s) for MGYA00175768...
# Download complete.
#
# Processing MGYA00175780...
# Downloading 1 file(s) for MGYA00175780...
# Download complete.
#
# Processing MGYA00193584...
# Downloading 1 file(s) for MGYA00193584...
# Download complete.
#
# Processing MGYA00193589...
# Downloading 1 file(s) for MGYA00193589...
# Download complete.
#
# Processing MGYA00193640...
# Downloading 1 file(s) for MGYA00193640...
# Download complete.
#
# Processing MGYA00193666...
# Downloading 1 file(s) for MGYA00193666...
# Download complete.
#
# Processing MGYA00356058...
# No fasta files found for MGYA00356058. Saving 'no_fasta.txt'...
#
# Processing MGYA00359204...
# No fasta files found for MGYA00359204. Saving 'no_fasta.txt'...
#
# Processing MGYA00359204...
# No fasta files found for MGYA00359204. Saving 'no_fasta.txt'...
#
# Processing MGYA00359205...
# No fasta files found for MGYA00359205. Saving 'no_fasta.txt'...
#
# Processing MGYA00572459...
# Downloading 1 file(s) for 3911928753...
# Download complete.
#
# Processing MGYA00572459...
# Downloading 1 file(s) for 3911629200...
# Download complete.
#
# Processing MGYA00572463...
# Downloading 1 file(s) for 3911468762...
# Download complete.
#
# Processing MGYA00572463...
# Downloading 1 file(s) for 3911762687...
# Download complete.
#
# Processing MGYA00572466...
# Downloading 1 file(s) for 3911917297...
# Download complete.
#
# Processing MGYA00572466...
# Downloading 1 file(s) for 3911968409...
# Download complete.
#
# Processing MGYA00284926...
# Downloading 1 file(s) for 2016605179...
# Download complete.
#
# Processing MGYA00284926...
# Downloading 1 file(s) for 2016605095...
# Download complete.
#
# Processing MGYA00285051...
# Downloading 1 file(s) for 2016689822...
# Download complete.
#
# Processing MGYA00285051...
# Downloading 1 file(s) for 2016689826...
# Download complete.
#
# Processing MGYA00285274...
# Downloading 1 file(s) for 2017807187...
# Download complete.
#
# Processing MGYA00285461...
# Downloading 1 file(s) for 2017906476...
# Download complete.
#
# Processing MGYA00285578...
# Downloading 1 file(s) for 2018110966...
# Download complete.
#
# Processing MGYA00288620...
# Downloading 1 file(s) for 2019067731...
# Download complete.
#
# Processing MGYA00288620...
# Downloading 1 file(s) for 2019067716...
# Download complete.
#
# Processing MGYA00288679...
# Downloading 1 file(s) for 2019105141...
# Download complete.
#
# Processing MGYA00288679...
# Downloading 1 file(s) for 2019105144...
# Download complete.
#
# Processing MGYA00288768...
# Downloading 1 file(s) for 2019146979...
# Download complete.
#
# Processing MGYA00288768...
# Downloading 1 file(s) for 2019147008...
# Download complete.
#
# Processing MGYA00288924...
# Downloading 1 file(s) for 2019218147...
# Download complete.
#
# Processing MGYA00288924...
# Downloading 1 file(s) for 2019218153...
# Download complete.
#
# Processing MGYA00289331...
# Downloading 1 file(s) for 2019427024...
# Download complete.
#
# Processing MGYA00289481...
# Downloading 1 file(s) for 2019497502...
# Download complete.
#
# Processing MGYA00290040...
# Downloading 1 file(s) for 2019815949...
# Download complete.
#
# Processing MGYA00290040...
# Downloading 1 file(s) for 2019815953...
# Download complete.
#
# Processing MGYA00290401...
# Downloading 1 file(s) for 2020114165...
# Download complete.
#
# Processing MGYA00284974...
# Downloading 1 file(s) for 2016637656...
# Download complete.
#
# Processing MGYA00284984...
# Downloading 1 file(s) for 2016646375...
# Download complete.
#
# Processing MGYA00285246...
# Downloading 1 file(s) for 2017786263...
# Download complete.
#
# Processing MGYA00285332...
# Downloading 1 file(s) for 2017840619...
# Download complete.
#
# Processing MGYA00288618...
# Downloading 1 file(s) for 2019065367...
# Download complete.
#
# Processing MGYA00288720...
# Downloading 1 file(s) for 2019129897...
# Download complete.
#
# Processing MGYA00288833...
# Downloading 1 file(s) for 2019182582...
# Download complete.
#
# Processing MGYA00288944...
# Downloading 1 file(s) for 2019234863...
# Download complete.
#
# Processing MGYA00175586...
# Downloading 1 file(s) for 2025492791...
# Download complete.
#
# Processing MGYA00175518...
# Downloading 1 file(s) for 2025430929...
# Download complete.
#
# Processing MGYA00175521...
# Downloading 1 file(s) for 2025434184...
# Download complete.
#
# Processing MGYA00175530...
# Downloading 1 file(s) for 2025441319...
# Download complete.
#
# Processing MGYA00175537...
# Downloading 1 file(s) for 2025448610...
# Download complete.
#
# Processing MGYA00175545...
# Downloading 1 file(s) for 2025458360...
# Download complete.
#
# Processing MGYA00175588...
# Downloading 1 file(s) for 2025494140...
# Download complete.
#
# Processing MGYA00175588...
# Downloading 1 file(s) for 2025494142...
# Download complete.
#
# Processing MGYA00175596...
# Downloading 1 file(s) for 2025502831...
# Download complete.
#
# Processing MGYA00175607...
# Downloading 1 file(s) for 2025513150...
# Download complete.
#
# Processing MGYA00175610...
# Downloading 1 file(s) for 2025516482...
# Download complete.
#
# Processing MGYA00284962...
# Downloading 1 file(s) for 2016628460...
# Download complete.
#
# Processing MGYA00284962...
# Downloading 1 file(s) for 2016628376...
# Download complete.
#
# Processing MGYA00290313...
# Downloading 1 file(s) for 2020037512...
# Download complete.
#
# Processing MGYA00290313...
# Downloading 1 file(s) for 2020037234...
# Download complete.
#
# Processing MGYA00572848...
# Downloading 1 file(s) for 3910414150...
# Download complete.
#
# Processing MGYA00572992...
# Downloading 1 file(s) for 3910354839...
# Download complete.
#
# Processing MGYA00175542...
# Downloading 1 file(s) for 2025454150...
# Download complete.
#
# Processing MGYA00175544...
# Downloading 1 file(s) for 2025456915...
# Download complete.
#
# Processing MGYA00175544...
# Downloading 1 file(s) for 2025456919...
# Download complete.
#
# Processing MGYA00175555...
# Downloading 1 file(s) for 2025467651...
# Download complete.
#
# Processing MGYA00175555...
# Downloading 1 file(s) for 2025467655...
# Download complete.
#
# Processing MGYA00175579...
# Downloading 1 file(s) for 2025486689...
# Download complete.
#
# Processing MGYA00175579...
# Downloading 1 file(s) for 2025486691...
# Download complete.
#
# Processing MGYA00285431...
# Downloading 1 file(s) for 2017888644...
# Download complete.
#
# Processing MGYA00289694...
# Downloading 1 file(s) for 2019624059...
# Download complete.
#
# Processing MGYA00175540...
# Downloading 1 file(s) for 2025451888...
# Download complete.
#
# Processing MGYA00175553...
# Downloading 1 file(s) for 2025465724...
# Download complete.
#
# Processing MGYA00224503...
# No MAPSeq files found for 2014237914. Saving 'no_mapseq.txt'...
#
# Processing MGYA00224503...
# No MAPSeq files found for 2014237936. Saving 'no_mapseq.txt'...
#
# Processing MGYA00285116...
# Downloading 1 file(s) for 2016910580...
# Download complete.
#
# Processing MGYA00285276...
# Downloading 1 file(s) for 2017808478...
# Download complete.
#
# Processing MGYA00285276...
# Downloading 1 file(s) for 2017808457...
# Download complete.
#
# Processing MGYA00290180...
# Downloading 1 file(s) for 2019936409...
# Download complete.
#
# Processing MGYA00290226...
# Downloading 1 file(s) for 2019982591...
# Download complete.
#
# Processing MGYA00290226...
# Downloading 1 file(s) for 2019982817...
# Download complete.
#
# Processing MGYA00285088...
# Downloading 1 file(s) for 2016711956...
# Download complete.
#
# Processing MGYA00285088...
# Downloading 1 file(s) for 2016711960...
# Download complete.
#
# Processing MGYA00290481...
# Downloading 1 file(s) for 2020179464...
# Download complete.
#
# Processing MGYA00290481...
# Downloading 1 file(s) for 2020183808...
# Download complete.
#
# Processing MGYA00196025...
# No MAPSeq files found for 2025253067. Saving 'no_mapseq.txt'...
#
# Processing MGYA00196127...
# No MAPSeq files found for 2025334797. Saving 'no_mapseq.txt'...
#
# Processing MGYA00285935...
# Downloading 1 file(s) for 2018099228...
# Download complete.
#
# Processing MGYA00288989...
# Downloading 1 file(s) for 2019254913...
# Download complete.
#
# Processing MGYA00284880...
# Downloading 1 file(s) for 2016581059...
# Download complete.
#
# Processing MGYA00284880...
# Downloading 1 file(s) for 2016581050...
# Download complete.
#
# Processing MGYA00284966...
# Downloading 1 file(s) for 2016631331...
# Download complete.
#
# Processing MGYA00284966...
# Downloading 1 file(s) for 2016631257...
# Download complete.
#
# Processing MGYA00290224...
# Downloading 1 file(s) for 2019979461...
# Download complete.
#
# Processing MGYA00290224...
# Downloading 1 file(s) for 2019979479...
# Download complete.
#
# Processing MGYA00290361...
# Downloading 1 file(s) for 2020082614...
# Download complete.
#
# Processing MGYA00366867...
# Downloading 1 file(s) for 2441092059...
# Download complete.
#
# Processing MGYA00366869...
# Downloading 1 file(s) for 2441089573...
# Download complete.
#
# Processing MGYA00366869...
# Downloading 1 file(s) for 2441090378...
# Download complete.
#
# Processing MGYA00366873...
# Downloading 1 file(s) for 2441095404...
# Download complete.
#
# Processing MGYA00366927...
# Downloading 1 file(s) for 2441149719...
# Download complete.
#
# Processing MGYA00366927...
# Downloading 1 file(s) for 2441149694...
# Download complete.
#
# Processing MGYA00366933...
# Downloading 1 file(s) for 2441155592...
# Download complete.
#
# Processing MGYA00366933...
# Downloading 1 file(s) for 2441154235...
# Download complete.
#
# Processing MGYA00367013...
# Downloading 1 file(s) for 2441236557...
# Download complete.
#
# Processing MGYA00363372...
# Downloading 1 file(s) for 2440638689...
# Download complete.
#
# Processing MGYA00150472...
# Downloading 1 file(s) for 2026562528...
# Download complete.
#
# Processing MGYA00150473...
# Downloading 1 file(s) for 2026563311...
# Download complete.
#
# Processing MGYA00593820...
# Downloading 1 file(s) for 3911269285...
# Download complete.
#
# Processing MGYA00593820...
# Downloading 1 file(s) for 3911272647...
# Download complete.
#
# Processing MGYA00593821...
# Downloading 1 file(s) for 3911347993...
# Download complete.
#
# Processing MGYA00593821...
# Downloading 1 file(s) for 3911636745...
# Download complete.
#
# Processing MGYA00593822...
# Downloading 1 file(s) for 3911329816...
# Download complete.
#
# Processing MGYA00593822...
# Downloading 1 file(s) for 3911359854...
# Download complete.
#
# Processing MGYA00593830...
# Downloading 1 file(s) for 3911618223...
# Download complete.
#
# Processing MGYA00593857...
# Downloading 1 file(s) for 3911314083...
# Download complete.
#
# Processing MGYA00593918...
# Downloading 1 file(s) for 3911534695...
# Download complete.
#
# Processing MGYA00593955...
# Downloading 1 file(s) for 3911545554...
# Download complete.
#
# Processing MGYA00593959...
# Downloading 1 file(s) for 3911348246...
# Download complete.
#
# Processing MGYA00593959...
# Downloading 1 file(s) for 3911360137...
# Download complete.
#
# Processing MGYA00594010...
# Downloading 1 file(s) for 3911193247...
# Download complete.
#
# Processing MGYA00594010...
# Downloading 1 file(s) for 3911425399...
# Download complete.
#
# Processing MGYA00594036...
# Downloading 1 file(s) for 3911235733...
# Download complete.
#
# Processing MGYA00594045...
# Downloading 1 file(s) for 3911343746...
# Download complete.
#
# Processing MGYA00594053...
# Downloading 1 file(s) for 3911617610...
# Download complete.
#
# Processing MGYA00594086...
# Downloading 1 file(s) for 3911466779...
# Download complete.
#
# Processing MGYA00185577...
# Downloading 1 file(s) for 2024132886...
# Download complete.
#
# Processing MGYA00185581...
# Downloading 1 file(s) for 2024134713...
# Download complete.
#
# Processing MGYA00356971...
# No MAPSeq files found for 2442320380. Saving 'no_mapseq.txt'...
#
# Processing MGYA00357582...
# No MAPSeq files found for 2442598736. Saving 'no_mapseq.txt'...
#
# Processing MGYA00357645...
# No MAPSeq files found for 2442244699. Saving 'no_mapseq.txt'...
#
# Processing MGYA00356105...
# No MAPSeq files found for 2440437986. Saving 'no_mapseq.txt'...
#
# Processing MGYA00356448...
# No MAPSeq files found for 2440319442. Saving 'no_mapseq.txt'...
#
# Processing MGYA00193822...
# Downloading 1 file(s) for 2023176670...
# Download complete.
#
# Processing MGYA00193860...
# Downloading 1 file(s) for 2023211269...
# Download complete.
#
# Processing MGYA00193889...
# Downloading 1 file(s) for 2023238913...
# Download complete.
#
# Processing MGYA00356643...
# No MAPSeq files found for 2441900879. Saving 'no_mapseq.txt'...
#
# Processing MGYA00195075...
# No MAPSeq files found for 2024504962. Saving 'no_mapseq.txt'...
#
# Processing MGYA00195084...
# No MAPSeq files found for 2024510011. Saving 'no_mapseq.txt'...
#
# Processing MGYA00193789...
# Downloading 1 file(s) for 2023148613...
# Download complete.
#
# Processing MGYA00193816...
# Downloading 1 file(s) for 2023171459...
# Download complete.
#
# Processing MGYA00193828...
# Downloading 1 file(s) for 2023182093...
# Download complete.
#
# Processing MGYA00193831...
# Downloading 1 file(s) for 2023185805...
# Download complete.
#
# Processing MGYA00164055...
# Downloading 1 file(s) for 2021913070...
# Download complete.
#
# Processing MGYA00164285...
# Downloading 1 file(s) for 2022138903...
# Download complete.
#
# Processing MGYA00164888...
# Downloading 1 file(s) for 2022744880...
# Download complete.
#
# Processing MGYA00165246...
# Downloading 1 file(s) for 2023093891...
# Download complete.
#
# Processing MGYA00165855...
# Downloading 1 file(s) for 2023689648...
# Download complete.
#
# Processing MGYA00163691...
# Downloading 1 file(s) for 2021538623...
# Download complete.
#
# Processing MGYA00164202...
# Downloading 1 file(s) for 2022052858...
# Download complete.
#
# Processing MGYA00164416...
# Downloading 1 file(s) for 2022274465...
# Download complete.
#
# Processing MGYA00164957...
# Downloading 1 file(s) for 2022810925...
# Download complete.
#
# Processing MGYA00165658...
# Downloading 1 file(s) for 2023492334...
# Download complete.
#
# Processing MGYA00166032...
# Downloading 1 file(s) for 2023865779...
# Download complete.
#
# Processing MGYA00164335...
# Downloading 1 file(s) for 2022191289...
# Download complete.
#
# Processing MGYA00164615...
# Downloading 1 file(s) for 2022466845...
# Download complete.
#
# Processing MGYA00165623...
# Downloading 1 file(s) for 2023458522...
# Download complete.
#
# Processing MGYA00165856...
# Downloading 1 file(s) for 2023690957...
# Download complete.
#
# Processing MGYA00360219...
# No MAPSeq files found for 2440485105. Saving 'no_mapseq.txt'...
#
# Processing MGYA00360222...
# No MAPSeq files found for 2440494644. Saving 'no_mapseq.txt'...
#
# Processing MGYA00214227...
# Downloading 1 file(s) for 2026987836...
# Download complete.
#
# Processing MGYA00356656...
# No MAPSeq files found for 2441940582. Saving 'no_mapseq.txt'...
#
# Processing MGYA00175741...
# Downloading 1 file(s) for 2025509463...
# Download complete.
#
# Processing MGYA00175745...
# Downloading 1 file(s) for 2025513479...
# Download complete.
#
# Processing MGYA00175762...
# Downloading 1 file(s) for 2025527673...
# Download complete.
#
# Processing MGYA00175768...
# Downloading 1 file(s) for 2025532309...
# Download complete.
#
# Processing MGYA00175780...
# Downloading 1 file(s) for 2025542205...
MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/2441133569/SRR5590684_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2441133569/SRR5590684_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/2019333082/SRR7595818_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2019333082/SRR7595818_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/3911360137/ERR867676_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/3911360137/ERR867676_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2022810925/SRR5177312_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2022810925/SRR5177312_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/2019927743/SRR7596896_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2019927743/SRR7596896_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/2016620941/SRR7034844_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2016620941/SRR7034844_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/2441232438/SRR5590781_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/2441232438/SRR5590781_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2018099228/SRR7035832_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2018099228/SRR7035832_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/2020082614/SRR7597093_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/2020082614/SRR7597093_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2441225223/SRR5590773_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2441225223/SRR5590773_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/2018122263/SRR7035875_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2018122263/SRR7035875_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/2017915632/SRR7035379_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2017915632/SRR7035379_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/2017959392/SRR7035475_MERGED_FASTQ_SSU.fasta.gz
# Extracted and deleted: /content/1/2017959392/SRR7035475_MERGED_FASTQ_SSU_MAPSeq.mseq.gz
# Extracted and deleted: /content/1/2441206485/SRR5590753_MERGED_FASTQ_SSU.fasta.gz
# ...
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2025456915
# Analyzing subdirectory: 2025456915
# Found FASTA file: /content/1/2025456915/ERR2233263_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441210769
# Analyzing subdirectory: 2441210769
# Found FASTA file: /content/1/2441210769/SRR5590759_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/3911348246
# Analyzing subdirectory: 3911348246
# Found FASTA file: /content/1/3911348246/ERR867676_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2025494142
# Analyzing subdirectory: 2025494142
# Found FASTA file: /content/1/2025494142/ERR2233233_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/occurrences.csv
# Skipping non-directory: occurrences.csv
# subdirectory path: /content/1/2023238913
# Analyzing subdirectory: 2023238913
# Found FASTA file: /content/1/2023238913/SRR1824377_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2018005377
# Analyzing subdirectory: 2018005377
# Found FASTA file: /content/1/2018005377/SRR7035582_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2016659033
# Analyzing subdirectory: 2016659033
# Found FASTA file: /content/1/2016659033/SRR7034901_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441021323
# Analyzing subdirectory: 2441021323
# Found FASTA file: /content/1/2441021323/SRR5590591_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2017696519
# Analyzing subdirectory: 2017696519
# Found FASTA file: /content/1/2017696519/SRR7035051_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2025486689
# Analyzing subdirectory: 2025486689
# Found FASTA file: /content/1/2025486689/ERR2233264_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2016631331
# Analyzing subdirectory: 2016631331
# Found FASTA file: /content/1/2016631331/SRR7034857_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2016605179
# Analyzing subdirectory: 2016605179
# Found FASTA file: /content/1/2016605179/SRR7034815_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2019234863
# Analyzing subdirectory: 2019234863
# Found FASTA file: /content/1/2019234863/SRR7595361_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/3911329816
# Analyzing subdirectory: 3911329816
# Found FASTA file: /content/1/3911329816/ERR867926_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441149694
# Analyzing subdirectory: 2441149694
# Found FASTA file: /content/1/2441149694/SRR5590700_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2014237936
# Analyzing subdirectory: 2014237936
# No FASTA files found in the subdirectory.
# subdirectory path: /content/1/2016628376
# Analyzing subdirectory: 2016628376
# Found FASTA file: /content/1/2016628376/SRR7034853_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2440927427
# Analyzing subdirectory: 2440927427
# Found FASTA file: /content/1/2440927427/SRR5590493_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441144943
# Analyzing subdirectory: 2441144943
# Found FASTA file: /content/1/2441144943/SRR5590698_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2025532309
# Analyzing subdirectory: 2025532309
# Found FASTA file: /content/1/2025532309/ERR1955014_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441031097
# Analyzing subdirectory: 2441031097
# Found FASTA file: /content/1/2441031097/SRR5590600_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2025486691
# Analyzing subdirectory: 2025486691
# Found FASTA file: /content/1/2025486691/ERR2233264_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2025451888
# Analyzing subdirectory: 2025451888
# Found FASTA file: /content/1/2025451888/ERR2233253_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2019067731
# Analyzing subdirectory: 2019067731
# Found FASTA file: /content/1/2019067731/SRR7595036_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441178131
# Analyzing subdirectory: 2441178131
# Found FASTA file: /content/1/2441178131/SRR5590729_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441132172
# Analyzing subdirectory: 2441132172
# Found FASTA file: /content/1/2441132172/SRR5590684_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/3917316439
# Analyzing subdirectory: 3917316439
# Found FASTA file: /content/1/3917316439/SRR6319737_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2025494140
# Analyzing subdirectory: 2025494140
# Found FASTA file: /content/1/2025494140/ERR2233233_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2019979479
# Analyzing subdirectory: 2019979479
# Found FASTA file: /content/1/2019979479/SRR7596946_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441142612
# Analyzing subdirectory: 2441142612
# Found FASTA file: /content/1/2441142612/SRR5590691_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2020044377
# Analyzing subdirectory: 2020044377
# Found FASTA file: /content/1/2020044377/SRR7597046_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441239192
# Analyzing subdirectory: 2441239192
# Found FASTA file: /content/1/2441239192/SRR5590789_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2017896791
# Analyzing subdirectory: 2017896791
# Found FASTA file: /content/1/2017896791/SRR7035343_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441103600
# Analyzing subdirectory: 2441103600
# Found FASTA file: /content/1/2441103600/SRR5590653_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441052383
# Analyzing subdirectory: 2441052383
# Found FASTA file: /content/1/2441052383/SRR5590610_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2023492334
# Analyzing subdirectory: 2023492334
# Found FASTA file: /content/1/2023492334/SRR5180067_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441163494
# Analyzing subdirectory: 2441163494
# Found FASTA file: /content/1/2441163494/SRR5590713_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2440980316
# Analyzing subdirectory: 2440980316
# Found FASTA file: /content/1/2440980316/SRR5590552_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2025465724
# Analyzing subdirectory: 2025465724
# Found FASTA file: /content/1/2025465724/ERR2233257_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2019410039
# Analyzing subdirectory: 2019410039
# Found FASTA file: /content/1/2019410039/SRR7595905_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2026563311
# Analyzing subdirectory: 2026563311
# Found FASTA file: /content/1/2026563311/ERR2215868_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441265766
# Analyzing subdirectory: 2441265766
# No FASTA files found in the subdirectory.
# subdirectory path: /content/1/2020037234
# Analyzing subdirectory: 2020037234
# Found FASTA file: /content/1/2020037234/SRR7597040_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2017821302
# Analyzing subdirectory: 2017821302
# Found FASTA file: /content/1/2017821302/SRR7035195_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2440935117
# Analyzing subdirectory: 2440935117
# Found FASTA file: /content/1/2440935117/SRR5590500_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2019288857
# Analyzing subdirectory: 2019288857
# Found FASTA file: /content/1/2019288857/SRR7595699_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2016900124
# Analyzing subdirectory: 2016900124
# Found FASTA file: /content/1/2016900124/SRR7035006_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2442320380
# Analyzing subdirectory: 2442320380
# No FASTA files found in the subdirectory.
# subdirectory path: /content/1/2019182582
# Analyzing subdirectory: 2019182582
# Found FASTA file: /content/1/2019182582/SRR7595249_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2020082747
# Analyzing subdirectory: 2020082747
# Found FASTA file: /content/1/2020082747/SRR7597093_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2440983423
# Analyzing subdirectory: 2440983423
# Found FASTA file: /content/1/2440983423/SRR5590555_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441109858
# Analyzing subdirectory: 2441109858
# Found FASTA file: /content/1/2441109858/SRR5590660_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441172326
# Analyzing subdirectory: 2441172326
# Found FASTA file: /content/1/2441172326/SRR5590725_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2019295277
# Analyzing subdirectory: 2019295277
# Found FASTA file: /content/1/2019295277/SRR7595714_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2017952452
# Analyzing subdirectory: 2017952452
# Found FASTA file: /content/1/2017952452/SRR7035462_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/3911235733
# Analyzing subdirectory: 3911235733
# Found FASTA file: /content/1/3911235733/ERR867821_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2440966276
# Analyzing subdirectory: 2440966276
# Found FASTA file: /content/1/2440966276/SRR5590535_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2019254913
# Analyzing subdirectory: 2019254913
# Found FASTA file: /content/1/2019254913/SRR7595406_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2440437986
# Analyzing subdirectory: 2440437986
# No FASTA files found in the subdirectory.
# subdirectory path: /content/1/2019239532
# Analyzing subdirectory: 2019239532
# Found FASTA file: /content/1/2019239532/SRR7595381_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2019936409
# Analyzing subdirectory: 2019936409
# Found FASTA file: /content/1/2019936409/SRR7596902_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2019982817
# Analyzing subdirectory: 2019982817
# Found FASTA file: /content/1/2019982817/SRR7596948_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441001063
# Analyzing subdirectory: 2441001063
# Found FASTA file: /content/1/2441001063/SRR5590567_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2441221271
# Analyzing subdirectory: 2441221271
# Found FASTA file: /content/1/2441221271/SRR5590768_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2016637656
# Analyzing subdirectory: 2016637656
# Found FASTA file: /content/1/2016637656/SRR7034865_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2020045888
# Analyzing subdirectory: 2020045888
# Found FASTA file: /content/1/2020045888/SRR7597046_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/3911928753
# Analyzing subdirectory: 3911928753
# No FASTA files found in the subdirectory.
# subdirectory path: /content/1/2441146097
# Analyzing subdirectory: 2441146097
# Found FASTA file: /content/1/2441146097/SRR5590698_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/3911359854
# Analyzing subdirectory: 3911359854
# Found FASTA file: /content/1/3911359854/ERR867926_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/3911314083
# Analyzing subdirectory: 3911314083
# Found FASTA file: /content/1/3911314083/ERR867830_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2023458522
# Analyzing subdirectory: 2023458522
# Found FASTA file: /content/1/2023458522/SRR5179989_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2440638689
# Analyzing subdirectory: 2440638689
# Found FASTA file: /content/1/2440638689/SRR7649441_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2026987836
# Analyzing subdirectory: 2026987836
# Found FASTA file: /content/1/2026987836/SRR1647972_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2016605095
# Analyzing subdirectory: 2016605095
# Found FASTA file: /content/1/2016605095/SRR7034815_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2024134713
# Analyzing subdirectory: 2024134713
# Found FASTA file: /content/1/2024134713/SRR6292372_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2025441319
# Analyzing subdirectory: 2025441319
# Found FASTA file: /content/1/2025441319/ERR2233242_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2440959875
# Analyzing subdirectory: 2440959875
# Found FASTA file: /content/1/2440959875/SRR5590530_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# subdirectory path: /content/1/2019067716
# Analyzing subdirectory: 2019067716
# Found FASTA file: /content/1/2019067716/SRR7595036_MERGED_FASTQ_SSU.fasta
# Extraction and CSV creation complete for all FASTA files.
# Analysis complete! Run GINSA_ANALYSER to interpret your results.

# %% [markdown]
# TESTING ANALYZER

# %%
# Out:
# Combined sequences saved as 'seq_master.fasta' in the root directory.
# Overall Nucleotide Frequencies:
# A: 20906 (27.72%)
# T: 19580 (25.96%)
# C: 13972 (18.52%)
# G: 20965 (27.80%)
